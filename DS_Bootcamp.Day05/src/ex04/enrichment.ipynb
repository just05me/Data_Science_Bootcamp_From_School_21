# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Загружаем данные

# %%
data = pd.read_json("../ex02/auto.json")

# %% [markdown]
# ## Числа должны отображаться с двумя знаками после запятой

# %% [markdown]
# - `pd.options.display.float_format`
#
#     - Это настройка *pandas*, которая определяет, как форматировать числа с плавающей точкой при отображении
#
#     - `"{:,.2f}".format` - Указывает шаблон форматирования

# %%
pd.options.display.float_format = "{:,.2f}".format

# %% [markdown]
# ## Обогащение набора данных сэмплом

# %% [markdown]
# - Сэмпл не должен содержать новых комбинаций `CarNumber`, `Make` и `Model`
# - `Refund` и `Fines` можно взять любые из существующих значений в случайном порядке

# %% [markdown]
# ---

# %% [markdown]
# - `np.random.seed(21)`
#
#     - Устанавливает начальное значение `seed` для генератора случайных чисел в библиотеке *NumPy*
#
#     - Генератор случайных чисел использует это значение для создания предсказуемой последовательности случайных чисел
#
# - `data.sample(n=200, random_state=21)`
#
#     - `sample()` - извлекает случайную подвыборку строк из *DataFrame* `data`
#
#     - `random_state=21` - Задает начальное значение для генератора случайных чисел, обеспечивает воспроизводимость выборки
#
#
# - содержащий 200 случайно выбранных строк из `data` с сохранением всех столбцов

# %%
np.random.seed(21)

sample = data.sample(n=200, random_state=21)

sample
# Out:
#         CarNumber  Refund     Fines        Make   Model
# 445  M0299X197RUS       2 19,200.00        Ford   Focus
# 22   83298C154RUS       2  8,594.59        Ford   Focus
# 93   H957HY161RUS       1  2,000.00        Ford   Focus
# 173   T941CC96RUS       1  2,000.00        Ford   Focus
# 697  H966HY161RUS       1    500.00        Ford   Focus
# ..            ...     ...       ...         ...     ...
# 14   8182XX154RUS       1    200.00        Ford   Focus
# 623   X796TH96RUS       1    500.00        Ford   Focus
# 498  T011MY163RUS       2  4,000.00        Ford   Focus
# 536   T341CC96RUS       2  1,000.00  Volkswagen  Passat
# 520   T119CT96RUS       1  2,000.00        Ford   Focus
#
# [200 rows x 5 columns]

# %%
sample['Refund'] = np.random.choice(data['Refund'], size=200)

sample['Fines'] = np.random.choice(data['Fines'], size=200)

# %% [markdown]
# ## Объединить сэмпл с исходным DataFrame в новый DataFrame concat_rows

# %% [markdown]
# - `pd.concat([data, sample], axis=0, ignore_index=True)`
#
#     - `pd.concat()` - Функция для объединения *DataFrame* или *Series*
#
#     - `axis=0` - Oбъединение происходит по строкам вертикально, то есть строки `sample` добавляются под строки `data`
#
#     - `ignore_index=True` - Сбрасывает исходные индексы обоих *DataFrame*. Cоздает новый последовательный индекс

# %%
concat_rows = pd.concat([data, sample], axis=0, ignore_index=True)

concat_rows
# Out:
#         CarNumber  Refund     Fines        Make   Model
# 0    Y163O8161RUS       2  3,200.00        Ford   Focus
# 1     E432XX77RUS       1  6,500.00      Toyota   Camry
# 2     7184TT36RUS       1  2,100.00        Ford   Focus
# 3    X582HE161RUS       2  2,000.00        Ford   Focus
# 4    92918M178RUS       1  5,700.00        Ford   Focus
# ..            ...     ...       ...         ...     ...
# 920  8182XX154RUS       1    500.00        Ford   Focus
# 921   X796TH96RUS       2 40,600.00        Ford   Focus
# 922  T011MY163RUS       1  2,300.00        Ford   Focus
# 923   T341CC96RUS       2  7,100.00  Volkswagen  Passat
# 924   T119CT96RUS       2    200.00        Ford   Focus
#
# [925 rows x 5 columns]

# %% [markdown]
# ## Добавлеть новый столбец

# %% [markdown]
# #### `Year`
# - Series с именем Year, с случайными целыми числами от 1980 до 2019.

# %% [markdown]
# ---

# %% [markdown]
# - `np.random.randint(1980, 2020, size=len(concat_rows))`
#
#     - `np.random.randint(low, high, size)` - генерирует случайные целые числа
#
#         - `low=1980` - Минимальное значение
#
#         - `high=2020` - Максимальное значение
#
#         - `Максимальное значение` - Количество чисел, равное числу строк в `concat_rows`

# %%
np.random.seed(21)

years = pd.Series(np.random.randint(1980, 2020, size=len(concat_rows)), name='Year')

# %% [markdown]
# - Объедините `Series` с *DataFrame* `concat_rows`, итоговый *DataFrame* назовите `fines`

# %%
fines = pd.concat([concat_rows, years], axis=1)
fines
# Out:
#         CarNumber  Refund     Fines        Make   Model  Year
# 0    Y163O8161RUS       2  3,200.00        Ford   Focus  1989
# 1     E432XX77RUS       1  6,500.00      Toyota   Camry  1995
# 2     7184TT36RUS       1  2,100.00        Ford   Focus  1984
# 3    X582HE161RUS       2  2,000.00        Ford   Focus  2015
# 4    92918M178RUS       1  5,700.00        Ford   Focus  2014
# ..            ...     ...       ...         ...     ...   ...
# 920  8182XX154RUS       1    500.00        Ford   Focus  1981
# 921   X796TH96RUS       2 40,600.00        Ford   Focus  1992
# 922  T011MY163RUS       1  2,300.00        Ford   Focus  2007
# 923   T341CC96RUS       2  7,100.00  Volkswagen  Passat  2005
# 924   T119CT96RUS       2    200.00        Ford   Focus  1997
#
# [925 rows x 6 columns]

# %% [markdown]
# ## Обогащение данных из другого *DataFrame*

# %% [markdown]
# - `surname_data.iloc[0]` - Извлекает первую строку *DataFrame* где значения этой строки становятся новыми именами столбцов

# %%
surname_data = pd.read_json("../../datasets/surname.json")

surname_data.columns = surname_data.iloc[0]

surname_data = surname_data.drop(index=0)

surname_data
# Out:
# 0        NAME    COUNT RANK
# 1       ADAMS   427865   42
# 2       ALLEN   482607   33
# 3     ALVAREZ   233983   92
# 4    ANDERSON   784404   15
# 5      BAILEY   277845   72
# ..        ...      ...  ...
# 96   WILLIAMS  1625252    3
# 97     WILSON   801882   14
# 98       WOOD   250715   84
# 99     WRIGHT   458980   35
# 100     YOUNG   484447   32
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Создайте `Series` из фамилий без специальных символов

# %% [markdown]
# - `.values` - Преобразует *Series* в массив *NumPy*, содержащий только данные столбца без метаданных

# %%
surnames = surname_data["NAME"].values

# %%
unique_cars = fines['CarNumber'].unique()

np.random.seed(21)

chosen_surnames = np.random.choice(surnames, size=len(unique_cars), replace=True)

owners = pd.DataFrame({
    "CarNumber": unique_cars,
    "SURNAME": chosen_surnames
})

owners
# Out:
#         CarNumber     SURNAME
# 0    Y163O8161RUS  RICHARDSON
# 1     E432XX77RUS        ROSS
# 2     7184TT36RUS      MORGAN
# 3    X582HE161RUS      BAILEY
# 4    92918M178RUS       LOPEZ
# ..            ...         ...
# 526  O136HO197RUS    CAMPBELL
# 527  O22097197RUS        HALL
# 528  M0309X197RUS       BAKER
# 529  O673E8197RUS        DIAZ
# 530  8610T8154RUS      MORGAN
#
# [531 rows x 2 columns]

# %% [markdown]
# ## Добавьте 5 дополнительных записей в *DataFrame* `fines`

# %%
new_fines = pd.DataFrame({
    'CarNumber': ['X123YZ77RUS', 'Y456AB77RUS', 'Z789CD77RUS', 'A012EF77RUS', 'B345GH77RUS'],
    'Refund': [1.0, 2.0, 1.0, 2.0, 1.0],
    'Fines': [5000.0, 3200.0, 4100.0, 2800.0, 7500.0],
    'Make': ['Honda', 'Nissan', 'Kia', 'Hyundai', 'Mazda'],
    'Model': ['Civic', 'Sentra', 'Rio', 'Elantra', '3'],
    'Year': [1995, 2005, 2010, 2015, 2018]
})

fines = pd.concat([fines, new_fines], ignore_index=True)

# %% [markdown]
# ## Удалите последние 20 записей из *DataFrame* `owners` и добавьте 3 новые

# %%
owners = owners[:-20]

new_owners = pd.DataFrame({
    'CarNumber': ['C678IJ77RUS', 'D901KL77RUS', 'E234MN77RUS'],
    'SURNAME': ['SMITH', 'JOHNSON', 'WILLIAMS']
})

owners = pd.concat([owners, new_owners], ignore_index=True)

# %% [markdown]
# ## Объедините оба *DataFrame* разными способами

# %% [markdown]
# - `merge()` - для объединения двух DataFrame на основе общего столбца
#
# - `on="CarNumber"` - Указывает столбец, по которому выполняется соединение
#
# - `how="inner"`
#
#     - *Inner join*:
#         - Включает только строки, где *CarNumber* присутствует в обоих *DataFrame*.
#         - Если *CarNumber* есть в `fines`, но отсутствует в `owners` или наоборот, эти строки исключаются

# %% [markdown]
# - DataFrame только с номерами машин, присутствующими в обоих *DataFrame*

# %%
common_df = fines.merge(owners, on='CarNumber', how='inner')

common_df
# Out:
#         CarNumber  Refund     Fines        Make   Model  Year     SURNAME
# 0    Y163O8161RUS    2.00  3,200.00        Ford   Focus  1989  RICHARDSON
# 1     E432XX77RUS    1.00  6,500.00      Toyota   Camry  1995        ROSS
# 2     7184TT36RUS    1.00  2,100.00        Ford   Focus  1984      MORGAN
# 3    X582HE161RUS    2.00  2,000.00        Ford   Focus  2015      BAILEY
# 4    92918M178RUS    1.00  5,700.00        Ford   Focus  2014       LOPEZ
# ..            ...     ...       ...         ...     ...   ...         ...
# 894  8182XX154RUS    1.00    500.00        Ford   Focus  1981       SMITH
# 895   X796TH96RUS    2.00 40,600.00        Ford   Focus  1992      WATSON
# 896  T011MY163RUS    1.00  2,300.00        Ford   Focus  2007     SANDERS
# 897   T341CC96RUS    2.00  7,100.00  Volkswagen  Passat  2005       PEREZ
# 898   T119CT96RUS    2.00    200.00        Ford   Focus  1997        RUIZ
#
# [899 rows x 7 columns]

# %% [markdown]
# - *DataFrame* со всеми номерами машин, которые есть в обоих

# %% [markdown]
# - `how="outer"` - Включает все строки из fines и owners

# %%
full_df = fines.merge(owners, on='CarNumber', how='outer')

full_df
# Out:
#         CarNumber  Refund     Fines  Make  Model     Year   SURNAME
# 0    704687163RUS    2.00  1,400.00  Ford  Focus 2,004.00     ADAMS
# 1    704787163RUS    2.00  2,800.00  Ford  Focus 1,992.00    MORGAN
# 2    704987163RUS    2.00  8,594.59  Ford  Focus 1,985.00  MITCHELL
# 3    705287163RUS    2.00  2,000.00  Ford  Focus 1,980.00     GOMEZ
# 4    705387163RUS    2.00    700.00  Ford  Focus 1,987.00   STEWART
# ..            ...     ...       ...   ...    ...      ...       ...
# 928  Y973O8197RUS    1.00 34,800.00  Ford  Focus 2,003.00     YOUNG
# 929  Y973O8197RUS    1.00 69,600.00  Ford  Focus 2,017.00     YOUNG
# 930  Y973O8197RUS    2.00  7,600.00  Ford  Focus 1,987.00     YOUNG
# 931  Y973O8197RUS    2.00  6,000.00  Ford  Focus 1,999.00     YOUNG
# 932   Z789CD77RUS    1.00  4,100.00   Kia    Rio 2,010.00       NaN
#
# [933 rows x 7 columns]

# %% [markdown]
# - *DataFrame* только с номерами из `fines`

# %% [markdown]
# - `how="left"` - Сохраняет все строки из fines

# %%
fines_only_df = fines.merge(owners, on='CarNumber', how='left')

fines_only_df
# Out:
#         CarNumber  Refund    Fines     Make    Model  Year     SURNAME
# 0    Y163O8161RUS    2.00 3,200.00     Ford    Focus  1989  RICHARDSON
# 1     E432XX77RUS    1.00 6,500.00   Toyota    Camry  1995        ROSS
# 2     7184TT36RUS    1.00 2,100.00     Ford    Focus  1984      MORGAN
# 3    X582HE161RUS    2.00 2,000.00     Ford    Focus  2015      BAILEY
# 4    92918M178RUS    1.00 5,700.00     Ford    Focus  2014       LOPEZ
# ..            ...     ...      ...      ...      ...   ...         ...
# 925   X123YZ77RUS    1.00 5,000.00    Honda    Civic  1995         NaN
# 926   Y456AB77RUS    2.00 3,200.00   Nissan   Sentra  2005         NaN
# 927   Z789CD77RUS    1.00 4,100.00      Kia      Rio  2010         NaN
# 928   A012EF77RUS    2.00 2,800.00  Hyundai  Elantra  2015         NaN
# 929   B345GH77RUS    1.00 7,500.00    Mazda        3  2018         NaN
#
# [930 rows x 7 columns]

# %% [markdown]
# - *DataFrame* только с номерами из `owners`

# %% [markdown]
# - `how="right"` - Сохраняет все строки из owners

# %%
owners_only_df = fines.merge(owners, on='CarNumber', how='right')

owners_only_df
# Out:
#         CarNumber  Refund     Fines    Make    Model     Year     SURNAME
# 0    Y163O8161RUS    2.00  3,200.00    Ford    Focus 1,989.00  RICHARDSON
# 1    Y163O8161RUS    2.00  1,600.00    Ford    Focus 1,980.00  RICHARDSON
# 2     E432XX77RUS    1.00  6,500.00  Toyota    Camry 1,995.00        ROSS
# 3     E432XX77RUS    2.00 13,000.00  Toyota    Camry 2,018.00        ROSS
# 4     7184TT36RUS    1.00  2,100.00    Ford    Focus 1,984.00      MORGAN
# ..            ...     ...       ...     ...      ...      ...         ...
# 897  7608EE777RUS    1.00  4,000.00   Skoda  Octavia 2,000.00        HILL
# 898  7608EE777RUS    2.00    900.00   Skoda  Octavia 1,991.00        HILL
# 899   C678IJ77RUS     NaN       NaN     NaN      NaN      NaN       SMITH
# 900   D901KL77RUS     NaN       NaN     NaN      NaN      NaN     JOHNSON
# 901   E234MN77RUS     NaN       NaN     NaN      NaN      NaN    WILLIAMS
#
# [902 rows x 7 columns]

# %% [markdown]
# ## Постройте сводную таблицу `pivot table` ИЗ `fines`

# %% [markdown]
# - где значения — это суммы штрафов `Fines` по годам `Year`

# %%
pivot_table = fines.pivot_table(index='Make', columns='Year', values='Fines', aggfunc='sum')

pivot_table
# Out:
# Year            1980       1981       1982      1983       1984       1985  \
# Make
# Audi             NaN        NaN        NaN       NaN        NaN        NaN
# BMW              NaN        NaN        NaN       NaN        NaN        NaN
# Ford       75,694.59 687,789.17 163,578.35 71,489.17 105,994.59 112,783.76
# Honda            NaN        NaN        NaN       NaN        NaN        NaN
# Hyundai          NaN        NaN        NaN       NaN        NaN        NaN
# Kia              NaN        NaN        NaN       NaN        NaN        NaN
# Mazda            NaN        NaN        NaN       NaN        NaN        NaN
# Nissan           NaN        NaN        NaN       NaN        NaN        NaN
# Skoda      10,494.59        NaN  10,900.00 11,594.59        NaN  10,294.59
# Toyota     12,000.00   8,594.59   2,000.00  7,200.00        NaN        NaN
# Volkswagen 30,900.00   1,600.00        NaN 11,794.59  10,300.00  34,800.00
# Volvo            NaN        NaN   6,800.00       NaN        NaN        NaN
#
# Year            1986       1987       1988       1989  ...       2010  \
# Make                                                   ...
# Audi             NaN        NaN        NaN   3,000.00  ...        NaN
# BMW              NaN        NaN        NaN        NaN  ...        NaN
# Ford       93,994.59 121,900.00 167,094.59 102,600.00  ... 141,989.17
# Honda            NaN        NaN        NaN        NaN  ...        NaN
# Hyundai          NaN        NaN        NaN        NaN  ...        NaN
# Kia              NaN        NaN        NaN        NaN  ...   4,100.00
# Mazda            NaN        NaN        NaN        NaN  ...        NaN
# Nissan           NaN        NaN        NaN        NaN  ...        NaN
# Skoda         600.00   5,200.00   1,500.00  91,400.00  ...   3,100.00
# Toyota           NaN   9,000.00        NaN  26,400.00  ...  24,000.00
# Volkswagen 22,400.00  24,200.00        NaN   5,800.00  ...   9,100.00
# Volvo            NaN        NaN        NaN        NaN  ...        NaN
#
# Year             2011       2012       2013       2014       2015       2016  \
# Make
# Audi              NaN        NaN        NaN        NaN        NaN        NaN
# BMW               NaN   3,200.00        NaN        NaN   8,594.59        NaN
# Ford       124,389.17 127,300.00 199,594.59 112,394.59 203,300.00 137,394.59
# Honda             NaN        NaN        NaN        NaN        NaN        NaN
# Hyundai           NaN        NaN        NaN        NaN   2,800.00        NaN
# Kia               NaN        NaN        NaN        NaN        NaN        NaN
# Mazda             NaN        NaN        NaN        NaN        NaN        NaN
# Nissan            NaN        NaN        NaN        NaN        NaN        NaN
# Skoda          500.00     500.00  12,594.59     300.00  46,394.59     300.00
# Toyota       8,594.59  10,594.59        NaN     900.00        NaN   9,600.00
# Volkswagen     300.00        NaN   6,000.00   1,300.00   3,400.00   2,100.00
# Volvo             NaN        NaN        NaN        NaN        NaN        NaN
#
# Year             2017       2018      2019
# Make
# Audi              NaN        NaN       NaN
# BMW               NaN   6,500.00       NaN
# Ford       309,400.00 267,594.59 88,700.00
# Honda             NaN        NaN       NaN
# Hyundai           NaN        NaN       NaN
# Kia               NaN        NaN       NaN
# Mazda             NaN   7,500.00       NaN
# Nissan            NaN        NaN       NaN
# Skoda        1,500.00 156,200.00  9,500.00
# Toyota       9,600.00  24,400.00 18,100.00
# Volkswagen        NaN  10,300.00       NaN
# Volvo             NaN        NaN 10,200.00
#
# [12 rows x 40 columns]

# %% [markdown]
# ## Сохраните оба DataFrame — `fines` и `owners`

# %% [markdown]
# - `fines`

# %%
fines.to_csv("fines.csv", index=False)

# %% [markdown]
# - `owners`

# %%
owners.to_csv("owners.csv", index=False)
